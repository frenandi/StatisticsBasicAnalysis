# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
datos_originales = pd.read_excel("baase de datos encuestas.xlsx",sheet_name="base datos")

# %%
print(datos_originales.columns)
# Out:
# Index(['Orden', 'Sección', 'Edad', 'Sexo', 'Muni Res', 'Depto Res',
#        'Título Div', 'Título Lic.', 'Trabajó', 'Salario', 'Estado conyugal',
#        'Medio de información', 'Soborno', 'copy paste'],
#       dtype='object')

# %%
datos_originales.drop(['Orden','Estado conyugal','copy paste','Soborno'],axis=1)
# Out:
#      Sección  Edad  Sexo                   Muni Res      Depto Res  \
# 0          2    26     1                  Chinautla      Guatemala
# 1          2    36     1              Villa Canales      Guatemala
# 2          2    24     2                  Guatemala      Guatemala
# 3          2    23     1                      Mixco      Guatemala
# 4          2    25     1                  Guatemala      Guatemala
# 5          2    24     2                  Guatemala      Guatemala
# 6          2    26     1                      Mixco      Guatemala
# 7          2    25     1                  Guatemala      Guatemala
# 8          2    25     1                  Guatemala      Guatemala
# 9          2    28     2                  San Lucas   Sacatepéquez
# 10         2    26     2                      Mixco      Guatemala
# 11         2    26     1                      Mixco      Guatemala
# 12         2    28     2                  Guatemala      Guatemala
# ...

# %% [markdown]
# # Analisis por Seccion

# %%
seccionA = datos_originales[datos_originales['Sección']==1]

# %%
seccionB = datos_originales[datos_originales['Sección']==2]

# %%
Hombres = datos_originales[datos_originales['Sexo']==1]

# %%
Mujeres = datos_originales[datos_originales['Sexo']==2]

# %%
seccionA.mean()
# Out:
# Orden                     85.500000
# Sección                    1.000000
# Edad                      26.100000
# Sexo                       1.700000
# Título Div                 2.300000
# Título Lic.                1.666667
# Trabajó                    1.450000
# Salario                 6551.983333
# Estado conyugal            1.266667
# Medio de información       3.666667
# Soborno                    1.083333
# copy paste                 1.250000
# dtype: float64

# %%
seccionB.mean()
# Out:
# Orden                     28.000000
# Sección                    2.000000
# Edad                      26.145455
# Sexo                       1.472727
# Título Div                 2.345455
# Título Lic.               26.072727
# Trabajó                    1.418182
# Salario                 3699.545455
# Estado conyugal            1.145455
# Medio de información       3.327273
# Soborno                    1.054545
# copy paste                 1.236364
# dtype: float64

# %%
Hombres.mean()
# Out:
# Orden                     57.196721
# Sección                    1.475410
# Edad                      26.442623
# Sexo                       1.000000
# Título Div                 2.327869
# Título Lic.               19.131148
# Trabajó                    1.426230
# Salario                 6514.737705
# Estado conyugal            1.196721
# Medio de información       3.508197
# Soborno                    1.032787
# copy paste                 1.229508
# dtype: float64

# %%
Mujeres.mean()
# Out:
# Orden                     58.365385
# Sección                    1.500000
# Edad                      25.711538
# Sexo                       2.000000
# Título Div                 2.365385
# Título Lic.                7.019231
# Trabajó                    1.423077
# Salario                 3830.673077
# Estado conyugal            1.192308
# Medio de información       3.480769
# Soborno                    1.115385
# copy paste                 1.269231
# dtype: float64

# %%
seccionA.median()
# Out:
# Orden                     85.5
# Sección                    1.0
# Edad                      25.0
# Sexo                       1.0
# Título Div                 1.0
# Título Lic.                1.0
# Trabajó                    1.0
# Salario                 2500.0
# Estado conyugal            1.0
# Medio de información       4.0
# Soborno                    1.0
# copy paste                 1.0
# dtype: float64

# %%
seccionB.median()
# Out:
# Orden                     28.0
# Sección                    2.0
# Edad                      25.0
# Sexo                       1.0
# Título Div                 1.0
# Título Lic.                1.0
# Trabajó                    1.0
# Salario                 2500.0
# Estado conyugal            1.0
# Medio de información       4.0
# Soborno                    1.0
# copy paste                 1.0
# dtype: float64

# %%
Hombres.median()
# Out:
# Orden                     58.0
# Sección                    1.0
# Edad                      25.0
# Sexo                       1.0
# Título Div                 1.0
# Título Lic.                1.0
# Trabajó                    1.0
# Salario                 2000.0
# Estado conyugal            1.0
# Medio de información       4.0
# Soborno                    1.0
# copy paste                 1.0
# dtype: float64

# %%
Mujeres.median()
# Out:
# Orden                     55.0
# Sección                    1.5
# Edad                      25.0
# Sexo                       2.0
# Título Div                 1.0
# Título Lic.                1.0
# Trabajó                    1.0
# Salario                 3000.0
# Estado conyugal            1.0
# Medio de información       4.0
# Soborno                    1.0
# copy paste                 1.0
# dtype: float64

# %%
seccionA.std()
# Out:
# Orden                      17.464249
# Sección                     0.000000
# Edad                        3.900022
# Sexo                        1.453226
# Título Div                  2.141598
# Título Lic.                 1.673995
# Trabajó                     0.501692
# Salario                 13798.625125
# Estado conyugal             0.685607
# Medio de información        1.002821
# Soborno                     0.278718
# copy paste                  0.473895
# dtype: float64

# %%
seccionB.std()
# Out:
# Orden                     16.020820
# Sección                    0.000000
# Edad                       3.057584
# Sexo                       0.503857
# Título Div                 3.186884
# Título Lic.               43.018021
# Trabajó                    0.497807
# Salario                 4515.094260
# Estado conyugal            0.487556
# Medio de información       1.306034
# Soborno                    0.229184
# copy paste                 0.428764
# dtype: float64

# %%
Hombres.std()
# Out:
# Orden                      34.249000
# Sección                     0.503539
# Edad                        4.047734
# Sexo                        0.000000
# Título Div                  2.625016
# Título Lic.                37.800562
# Trabajó                     0.498632
# Salario                 13732.849760
# Estado conyugal             0.572121
# Medio de información        1.259933
# Soborno                     0.179556
# copy paste                  0.424006
# dtype: float64
